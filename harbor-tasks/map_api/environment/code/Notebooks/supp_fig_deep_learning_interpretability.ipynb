# %% [markdown]
# # Supplementary figures for the interpretability of the deep learning models
#
# I am just replotting the data that was used for generating some figures for the reviewer responses to potentially use them as supplementary figures.
#
# The data comes from the final trained models on CCN.

# %%
import os
import sys
import numpy as np
import pickle
import matplotlib.pyplot as plt
import local_env 
from VideoAnalysisUtils import plot_style

# %%
datafolder = '../data/'
ae_latent_filename = 'session_latents.pkl'
e2e_saliency_filename = 'e2e_saliency_map_session_goode2e_bad_other.pickle'

latent_data = pickle.load(open(os.path.join(datafolder, ae_latent_filename), 'rb'))
saliency_data = pickle.load(open(os.path.join(datafolder, e2e_saliency_filename), 'rb'))

# %%
latent_data.keys()
# Out:
# dict_keys([np.str_('SC026_080519'), np.str_('SC026_080619'), np.str_('SC026_080819'), np.str_('SC027_072919'), np.str_('SC027_073019'), np.str_('SC027_073119'), np.str_('SC027_080119'), np.str_('SC027_080319'), np.str_('SC027_080419'), np.str_('SC030_100319'), np.str_('SC030_100419'), np.str_('SC030_100519'), np.str_('SC031_102119'), np.str_('SC031_102319'), np.str_('SC032_121819'), np.str_('SC032_121919'), np.str_('SC032_122019'), np.str_('SC033_111319'), np.str_('SC033_111419'), np.str_('SC033_111519'), np.str_('SC035_010720'), np.str_('SC035_010820'), np.str_('SC035_010920'), np.str_('SC035_011020'), np.str_('SC038_111919_s4'), np.str_('SC038_111919_s5'), np.str_('SC038_112019_s6'), np.str_('SC038_112019_s7'), np.str_('SC038_112119_s8'), np.str_('SC038_112119_s9'), np.str_('SC038_112219_s10'), np.str_('SC038_112219_s11'), np.str_('SC038_112319_s12'), np.str_('SC038_112319_s13'), np.str_('SC043_092220'), np.str_('SC043_092320'), np.str_('SC043_092420'), np.str_('SC043_092520'), np.str_('SC045_121020'), np.str_('SC045_121120'), np.str_('SC045_121420'), np.str_('SC045_121720'), np.str_('SC045_121820'), np.str_('SC048_010121'), np.str_('SC048_010321'), np.str_('SC048_010421'), np.str_('SC048_122520'), np.str_('SC048_122620'), np.str_('SC048_122920'), np.str_('SC048_123020'), np.str_('SC048_123120'), np.str_('SC049_010721'), np.str_('SC049_010821'), np.str_('SC049_011021'), np.str_('SC049_011121'), np.str_('SC049_011221'), np.str_('SC049_011321'), np.str_('SC050_022521'), np.str_('SC050_022621'), np.str_('SC050_022721'), np.str_('SC050_030121'), np.str_('SC050_030221'), np.str_('SC050_030321'), np.str_('SC050_030421'), np.str_('SC052_012121'), np.str_('SC052_012621'), np.str_('SC053_022121'), np.str_('SC053_022221'), np.str_('SC053_022421'), np.str_('SC053_022521'), np.str_('SC053_022621'), np.str_('SC060_031921'), np.str_('SC060_032021'), np.str_('SC060_032221'), np.str_('SC060_032321'), np.str_('SC061_032121'), np.str_('SC061_032221'), np.str_('SC061_032321'), np.str_('SC061_032421'), np.str_('SC064_042721'), np.str_('SC064_042821'), np.str_('SC064_042921'), np.str_('SC064_043021'), np.str_('SC064_050421'), np.str_('SC064_050621'), np.str_('SC064_050721'), np.str_('SC064_050821'), np.str_('SC065_050421'), np.str_('SC065_050621'), np.str_('SC065_050721'), np.str_('SC065_050921'), np.str_('SC065_051021'), np.str_('SC065_051121'), np.str_('SC065_051321'), np.str_('SC065_051421'), np.str_('SC066_041421'), np.str_('SC066_041521'), np.str_('SC066_041621'), np.str_('SC066_042021'), np.str_('SC066_042121'), np.str_('SC067_041321'), np.str_('SC067_041421'), np.str_('SC067_041521'), np.str_('SC067_041821'), np.str_('SC067_041921'), np.str_('SC067_042021')])

# %%
saliency_data.keys()
# Out:
# dict_keys(['single_neuron_saliency_maps', 'session_saliency_maps', 'example_background_images'])

# %%
plt.subplots(2,5, figsize=(7.8,3))

for i in range(10):
    plt.subplot(2,5,i+1)
    plt.title(f'Neuron {i}')
    plt.imshow(saliency_data['example_background_images'][i], cmap='gray')
    im = plt.imshow(saliency_data['single_neuron_saliency_maps'][i]/np.max(saliency_data['single_neuron_saliency_maps'][i]), 
                    cmap='hot', alpha = 0.8, vmin = 0, vmax = 1.)
    plt.colorbar(im, shrink=0.5, aspect=10)
    plt.axis('off')

plt.savefig('../figs/manuscript_drafts/' + 'Supp_e2e_saliency_map_single_neurons.pdf', dpi=300, bbox_inches='tight')

# %%
plt.subplots(2,5, figsize=(7.8,3))

for i in range(10):
    plt.subplot(2,5,i+1)
    plt.title(f'Session {i}')
    plt.imshow(saliency_data['example_background_images'][i], cmap='gray')
    im = plt.imshow(saliency_data['session_saliency_maps'][i]/np.max(saliency_data['session_saliency_maps'][i]), 
                    cmap='hot', alpha = 0.8, vmin = 0, vmax = 1.)
    plt.colorbar(im, shrink=0.5, aspect=10)
    plt.axis('off')

plt.savefig('../figs/manuscript_drafts/' + 'Supp_e2e_saliency_map_session.pdf', dpi=300, bbox_inches='tight')

# %%
f, axs = plt.subplots(5,5, figsize=(7.,6.1))

for i in range(10):
    plt.subplot(5,5,i+1)
    plt.title(f'Neuron {i}')
    plt.imshow(saliency_data['example_background_images'][i], cmap='gray')
    im = plt.imshow(saliency_data['single_neuron_saliency_maps'][i]/np.max(saliency_data['single_neuron_saliency_maps'][i]), 
                    cmap='hot', alpha = 0.8, vmin = 0, vmax = 1.)
    plt.colorbar(im, shrink=0.5, aspect=10)
    plt.axis('off')

    plt.subplot(5,5,i+1+15)
    plt.title(f'Session {i}')
    plt.imshow(saliency_data['example_background_images'][i], cmap='gray')
    im = plt.imshow(saliency_data['session_saliency_maps'][i]/np.max(saliency_data['session_saliency_maps'][i]), 
                    cmap='hot', alpha = 0.8, vmin = 0, vmax = 1.)
    plt.colorbar(im, shrink=0.5, aspect=10)
    plt.axis('off')

for i in range(5):
    plt.subplot(5,5,i+1+10)
    plt.axis('off')

f.text(0.1, 0.9, 'a', fontsize = 16)
f.text(0.1, 0.42, 'b', fontsize = 16)

plt.savefig('../figs/manuscript_drafts/' + 'Supp_e2e_saliency_maps_all.pdf', dpi=300, bbox_inches='tight')

# %%
latent_session = 'SC038_112319_s13'

f,_ = plt.subplots(4,4, figsize=(6.,6.))

for i in range(16):
    plt.subplot(4,4,i+1)
    plt.title('latent %d'%i)
    plt.imshow(latent_data[latent_session][i], vmin = -2, vmax = 2, cmap='bwr') 
    plt.xticks([])
    plt.yticks([])

f.suptitle(latent_session, fontsize = 12)
f.subplots_adjust(top=0.92)

plt.savefig('../figs/manuscript_drafts/' + 'Supp_ae_latent_session.pdf', dpi=300, bbox_inches='tight')
